# %% [markdown]
# # CRM Customer Analysis Project
# This notebook performs basic CRM-style analysis and visualization on the Amazon Sales dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('Amazon Sale Report.csv', low_memory=False)
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')
print(df.head())

# %% [markdown]
# ## 1) Sales over Time

# %%
daily_sales = df.groupby(df['Date'].dt.date)['Amount'].sum()
plt.figure()
daily_sales.plot()
plt.title('Daily Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Total Sales Amount')
plt.show()

# %% [markdown]
# ## 2) Revenue by Category

# %%
cat_revenue = df.groupby('Category')['Amount'].sum().sort_values(ascending=False)
plt.figure()
cat_revenue.plot(kind='bar')
plt.title('Revenue by Category')
plt.xlabel('Category')
plt.ylabel('Total Revenue')
plt.show()

# %% [markdown]
# ## 3) Orders by City (Top 10)

# %%
city_orders = df['ship-city'].value_counts().head(10)
plt.figure()
city_orders.plot(kind='bar')
plt.title('Top 10 Cities by Orders')
plt.xlabel('City')
plt.ylabel('Number of Orders')
plt.show()
